# %% [markdown]
# # Notebook for computing amino acid fitness mutations

# %% [markdown]
# ## Snakemake input

# %%
orf1ab_to_nsps=snakemake.params.orf_to_nsps
gene_overlaps=snakemake.params.gene_ov
fitness_pseudocount=snakemake.params.fit_pseudo
ntmut_fit=snakemake.input.ntfit_csv
output=snakemake.output.aafit_csv

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
import sys
import os

# %%
# Adding module folder to system paths
module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from modules import aamutfit

# %% [markdown]
# Columns to be exploded

# %%
explode_cols = [
    "gene",
    "clade_founder_aa",
    "mutant_aa",
    "codon_site",
    "aa_mutation",
]

# %% [markdown]
# Read data, then:
#
# * Exclude mutations in overlapping reading frames specified for exclusion
# * Explode dataframe to make a separate line for each gene.
# * Drop ORF1a, the reason being that after we exclude overlapping reading frame sites there aren't any ORF1a sites not also in ORF1ab.
# * Aggregate all expected and actual counts for the same amino acid change for each clade / amino-acid mutation

# %%
# Read-in fitness of nucleotide mutations
ntmut_fit = pd.read_csv(ntmut_fit)

# %%
ntmut_fit.head()
# Out:
#   cluster  nt_site nt_mutation       gene codon_site aa_mutation  synonymous  \
# 0    BA.2        1         A1C  noncoding  noncoding   noncoding       False
# 1    BA.2        1         A1T  noncoding  noncoding   noncoding       False
# 2    BA.2        1         A1G  noncoding  noncoding   noncoding       False
# 3    BA.2        2         T2A  noncoding  noncoding   noncoding       False
# 4    BA.2        2         T2C  noncoding  noncoding   noncoding       False
#
#    noncoding  expected_count  predicted_count  actual_count  tau_squared  \
# 0       True         2.76300         6.229330             0     1.133304
# 1       True         5.85249         2.605232             0     1.528482
# 2       True        22.54600        33.485375             0     1.264059
# 3       True         4.85726         1.214439             0     1.432641
# 4       True        19.84960        37.529563             0     1.408045
#
#       f_max  left_conf_int  right_conf_int    f_mean  f_st_dev
# 0 -2.573587       1.732517        1.361119 -2.916866  1.615931
# 1 -1.907730       1.980310        1.364161 -2.404429  1.708155
# 2 -3.651029       1.574816        1.351596 -3.921000  1.502344
# 3 -1.428756       2.124832        1.303251 -2.010018  1.777772
# 4 -3.679257       1.630200        1.296212 -3.980191  1.495832

# %% [markdown]
# Get only coding mutations

# %%
ntmut_fit_coding = aamutfit.get_coding(ntmut_fit, gene_overlaps, explode_cols)

# %%
ntmut_fit_coding.head()
# Out:
#     cluster  nt_site nt_mutation    gene codon_site aa_mutation  synonymous  \
# 795    BA.2      266       A266G  ORF1ab          1         M1V       False
# 796    BA.2      266       A266C  ORF1ab          1         M1L       False
# 797    BA.2      266       A266T  ORF1ab          1         M1L       False
# 798    BA.2      267       T267C  ORF1ab          1         M1T       False
# 799    BA.2      267       T267A  ORF1ab          1         M1K       False
#
#      noncoding  expected_count  predicted_count  ...  tau_squared     f_max  \
# 795      False        22.54600        33.016702  ...     0.885954 -3.757701
# 796      False         2.76300         8.187283  ...     1.047344 -2.774285
# 797      False         5.85249         1.668554  ...     1.416492 -0.003785
# 798      False        19.84960        41.542965  ...     1.414540 -2.914588
# 799      False         4.85726         4.712380  ...     1.432641 -0.792537
#
#      left_conf_int  right_conf_int    f_mean  f_st_dev  is_overlapping  \
# 795       1.551756        1.291045 -4.027320  1.458397           False
# 796       1.699045        1.394591 -3.096819  1.584339           False
# 797       1.254955        1.175321 -0.058746  1.221781           False
# 798       1.296379        1.175352 -3.048273  1.241749           False
# 799       1.223349        1.174102 -0.852807  1.206019           False
#
#      overlap_to_exclude  clade_founder_aa mutant_aa
# 795               False                 M         V
# 796               False                 M         L
# 797               False                 M         L
# 798               False                 M         T
# 799               False                 M         K
#
# [5 rows x 21 columns]

# %% [markdown]
# Aggregate counts for amino acid mutations

# %%
aa_counts = aamutfit.aggregate_counts(ntmut_fit_coding, explode_cols)

# %% [markdown]
# Adding naive fitness estimates

# %%
aamutfit.naive_fitness(aa_counts, fitness_pseudocount=fitness_pseudocount)

# %%
aa_counts.head()
# Out:
#   cluster gene clade_founder_aa mutant_aa  aa_site aa_mutation  \
# 0    BA.2    E                A         A       22        A22A
# 1    BA.2    E                A         A       32        A32A
# 2    BA.2    E                A         A       36        A36A
# 3    BA.2    E                A         A       41        A41A
# 4    BA.2    E                A         D       22        A22D
#
#    expected_count  predicted_count  actual_count  tau_squared  naive_fitness
# 0        27.39653        28.863105            10     4.393839      -0.977127
# 1       194.79774       103.357180           472     3.655382       0.883512
# 2       121.94270       146.546479            17     5.260903      -1.945442
# 3       121.94270       203.566927            76     5.492444      -0.470352
# 4        12.63590        12.906202             0     1.567256      -3.268496

# %% [markdown]
# Dataframe with refined fitness estimates

# %%
aa_fit = aamutfit.aa_fitness(ntmut_fit_coding, explode_cols)

# %% [markdown]
# In addition to the entries for full ORF1ab, we also want to have mutations numbered by the nsp naming.
#
# First, make a data frame that converts the numbering:

# %%
orf1ab_to_nsps_df = aamutfit.map_orf1ab_to_nsps(orf1ab_to_nsps)

# %% [markdown]
# Now we add to our dataframes that have ORF1ab the estimates for the nsp proteins. Note that these means mutations in both ORF1ab and nsp show up **twice** in the data frame with different names, so we add a column to indicate which genes are a subset of ORF1ab:

# %%
aa_counts = aamutfit.add_nsps(aa_counts, orf1ab_to_nsps_df)
aa_fit = aamutfit.add_nsps(aa_fit, orf1ab_to_nsps_df)

# %% [markdown]
# Merge counts and fitness dataframes and write to file

# %%
aamut_fitness = aamutfit.merge_aa_df(aa_fit, aa_counts, explode_cols)

# %%
aamut_fitness.head()
# Out:
#   cluster gene clade_founder_aa mutant_aa  aa_site aa_mutation  \
# 0    BA.2    E                A         A       22        A22A
# 1    BA.2    E                A         A       32        A32A
# 2    BA.2    E                A         A       36        A36A
# 3    BA.2    E                A         A       41        A41A
# 4    BA.2    E                A         D       22        A22D
#
#    expected_count  predicted_count  actual_count  tau_squared  naive_fitness  \
# 0        27.39653        28.863105            10     4.393839      -0.977127
# 1       194.79774       103.357180           472     3.655382       0.883512
# 2       121.94270       146.546479            17     5.260903      -1.945442
# 3       121.94270       203.566927            76     5.492444      -0.470352
# 4        12.63590        12.906202             0     1.567256      -3.268496
#
#    subset_of_ORF1ab  delta_fitness  uncertainty
# 0             False      -1.238764     0.750704
# 1             False       0.518985     0.575201
# 2             False      -1.777703     0.654703
# 3             False      -0.823123     0.624146
# 4             False      -3.319033     1.571656

# %%
aamut_fitness.to_csv(output, index=False)
