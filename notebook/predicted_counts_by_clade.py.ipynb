# %% [markdown]
# # Add predicted counts to clade-wise dataframe

# %% [markdown]
# ## Snakemake inputs

# %%
counts_df_csv = snakemake.input.counts_df
pre_omicron = snakemake.input.pre_omicron
omicron = snakemake.input.omicron
pred_count_csv = snakemake.output.pred_count_csv

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import sys
import os

# %%
# Adding module folder to system paths
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from modules import load
from modules import rates

# %% [markdown]
# ## Load dataframes

# %%
counts_by_clade = pd.read_csv(counts_df_csv, low_memory=False)

# %%
counts_by_clade.head()
# Out:
#   clade  nt_site nt_mutation  exclude  masked_in_usher  expected_count  \
# 0   20A        1         A1C     True             True         0.96873
# 1   20A        1         A1G     True             True         3.60910
# 2   20A        1         A1T     True             True         1.27820
# 3   20A        2         T2A     True             True         0.90342
# 4   20A        2         T2C     True             True         3.58890
#
#    actual_count clade_founder_nt       gene clade_founder_codon  ... mut_type  \
# 0             0                A  noncoding           noncoding  ...       AC
# 1             0                A  noncoding           noncoding  ...       AG
# 2             0                A  noncoding           noncoding  ...       AT
# 3             0                T  noncoding           noncoding  ...       TA
# 4             0                T  noncoding           noncoding  ...       TC
#
#    mut_class pre_omicron_or_omicron nt_site_before_boundary  ss_prediction  \
# 0  noncoding            pre_omicron                   False       unpaired
# 1  noncoding            pre_omicron                   False       unpaired
# 2  noncoding            pre_omicron                    True       unpaired
# 3  noncoding            pre_omicron                   False       unpaired
# 4  noncoding            pre_omicron                   False       unpaired
#
#    unpaired motif ref_motif  predicted_count  tau_squared
# 0         1   AAT       NaN         1.738421     0.433274
# 1         1   AAT       NaN         6.308562     0.736113
# 2         1   AAT       NaN         0.629081     0.635531
# 3         1   ATT       ATT         0.205190     0.520788
# 4         1   ATT       ATT         6.277356     0.719985
#
# [5 rows x 34 columns]

# %%
counts_pre_om = load.load_synonymous_muts(pre_omicron)

# %%
counts_om = load.load_synonymous_muts(omicron)

# %% [markdown]
# ## Populate with predicted counts

# %%
rates.add_predicted_count_all_clades(counts_pre_om, counts_om, counts_by_clade)

# %%
counts_by_clade.tail()
# Out:
#         clade  nt_site nt_mutation  exclude  masked_in_usher  expected_count  \
# 2422138   23I    29902     A29902G     True             True          3.6645
# 2422139   23I    29902     A29902T     True             True          1.2852
# 2422140   23I    29903     A29903C     True             True          0.4188
# 2422141   23I    29903     A29903G     True             True          3.6645
# 2422142   23I    29903     A29903T     True             True          1.2852
#
#          actual_count clade_founder_nt       gene clade_founder_codon  ...  \
# 2422138             0                A  noncoding           noncoding  ...
# 2422139             0                A  noncoding           noncoding  ...
# 2422140             0                A  noncoding           noncoding  ...
# 2422141             0                A  noncoding           noncoding  ...
# 2422142             0                A  noncoding           noncoding  ...
#
#         mut_type  mut_class pre_omicron_or_omicron nt_site_before_boundary  \
# 2422138       AG  noncoding                omicron                   False
# 2422139       AT  noncoding                omicron                   False
# 2422140       AC  noncoding                omicron                   False
# 2422141       AG  noncoding                omicron                   False
# 2422142       AT  noncoding                omicron                   False
#
#          ss_prediction  unpaired motif ref_motif  predicted_count  tau_squared
# 2422138             nd         0   AAA       AAA         2.526564     0.279517
# 2422139             nd         0   AAA       AAA         1.421710     0.751940
# 2422140             nd         0   AAA       NaN         0.559207     0.642931
# 2422141             nd         0   AAA       NaN         2.526564     0.279517
# 2422142             nd         0   AAA       NaN         1.421710     0.751940
#
# [5 rows x 34 columns]

# %%
counts_by_clade.to_csv(pred_count_csv, index=False)
